# %%
import pandas as pd

ALL_TOKENS = pd.read_csv('Data\CORPUS\FULL_CORPUS.csv')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\school\AppData\Local\Temp\ipykernel_89888\2844328.py:3: SyntaxWarning: invalid escape sequence '\C'
#   ALL_TOKENS = pd.read_csv('Data\CORPUS\FULL_CORPUS.csv')
# C:\Users\school\AppData\Local\Temp\ipykernel_89888\2844328.py:3: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ALL_TOKENS = pd.read_csv('Data\CORPUS\FULL_CORPUS.csv')

# %%
VOCAB = ALL_TOKENS.term_str.value_counts().to_frame('n')
VOCAB.index.name = 'term_str'

# %%
import numpy as np

VOCAB = ALL_TOKENS.term_str.value_counts().to_frame('n')
VOCAB.index.name = 'term_str'
VOCAB['p'] = VOCAB.n / VOCAB.n.sum()
VOCAB['i'] = -np.log2(VOCAB.p)
VOCAB['n_chars'] = VOCAB.index.str.len()
VOCAB
# Out:
#                n         p          i  n_chars
# term_str
# the        36126  0.056064   4.156784        3
# and        22280  0.034576   4.854073        3
# to         18949  0.029407   5.087700        2
# of         17802  0.027627   5.177783        2
# i          15207  0.023600   5.405086        1
# ...          ...       ...        ...      ...
# houseto        1  0.000002  19.297534        7
# mopboard       1  0.000002  19.297534        8
# slaps          1  0.000002  19.297534        5
# tramples       1  0.000002  19.297534        8
# arabesque      1  0.000002  19.297534        9
#
# [21504 rows x 4 columns]

# %%
VOCAB['max_pos_group'] = ALL_TOKENS[['term_str','pos_group']].value_counts().unstack(fill_value=0).idxmax(1)
VOCAB['max_pos'] = ALL_TOKENS[['term_str','pos']].value_counts().unstack(fill_value=0).idxmax(1)
VOCAB
# Out:
#                n         p          i  n_chars max_pos_group max_pos
# term_str
# the        36126  0.056064   4.156784        3            DT      DT
# and        22280  0.034576   4.854073        3            CC      CC
# to         18949  0.029407   5.087700        2            TO      TO
# of         17802  0.027627   5.177783        2            IN      IN
# i          15207  0.023600   5.405086        1            PR     PRP
# ...          ...       ...        ...      ...           ...     ...
# houseto        1  0.000002  19.297534        7           NaN     NaN
# mopboard       1  0.000002  19.297534        8           NaN     NaN
# slaps          1  0.000002  19.297534        5           NaN     NaN
# tramples       1  0.000002  19.297534        8           NaN     NaN
# arabesque      1  0.000002  19.297534        9           NaN     NaN
#
# [21504 rows x 6 columns]

# %%
TPM1 = ALL_TOKENS[['term_str','pos_group']].value_counts().unstack()
TPM1
VOCAB['n_pos_group'] = TPM1.count(1)
TPM2 = ALL_TOKENS[['term_str','pos']].value_counts().unstack()
VOCAB['n_pos'] = TPM2.count(1)

# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Collecting click (from nltk)
#   Downloading click-8.3.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: joblib in c:\users\school\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nltk) (1.5.1)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: tqdm in c:\users\school\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\school\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 348.1 kB/s eta 0:00:03
#    -------------------- ------------------- 0.8/1.6 MB 534.6 kB/s eta 0:00:02
#    -------------------- ------------------- 0.8/1.6 MB 534.6 kB/s eta 0:00:02
#    --------------------------- ------------ 1.0/1.6 MB 517.9 kB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 633.7 kB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 633.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 628.1 kB/s  0:00:02
# Downloading regex-2026.4.4-cp313-cp313-win_amd64.whl (277 kB)
# Downloading click-8.3.2-py3-none-any.whl (108 kB)
# Installing collected packages: regex, click, nltk
#
#    ---------------------------------------- 0/3 [regex]
#    ---------------------------------------- 0/3 [regex]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    -------------------------- ------------- 2/3 [nltk]
#    ---------------------------------------- 3/3 [nltk]
#
# Successfully installed click-8.3.2 nltk-3.9.4 regex-2026.4.4
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Users\school\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import nltk
nltk.download('stopwords')
sw = pd.DataFrame({'stop': 1}, index=nltk.corpus.stopwords.words('english'))
sw.index.name='term_str'
sw.head()
if 'stop' not in VOCAB.columns:
    VOCAB = VOCAB.join(sw)
    VOCAB['stop'] = VOCAB['stop'].fillna(0).astype('int')
VOCAB
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\corpus\util.py:85, in LazyCorpusLoader.__load(self)
#      84 try:
# ---> 85     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86 except LookupError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\data.py:738, in find(resource_name, paths)
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'stopwords' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/stopwords.zip/stopwords/'
#
#   Searched in:
#     - 'C:\\Users\\school/nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\share\\nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\lib\\nltk_data'
#     - 'C:\\Users\\school\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# Cell In[18], line 2
#       1 import nltk
# ----> 2 sw = pd.DataFrame({'stop': 1}, index=nltk.corpus.stopwords.words('english'))
#       3 sw.index.name='term_str'
#       4 sw.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\corpus\util.py:129, in LazyCorpusLoader.__getattr__(self, attr)
#     124 if attr.startswith("__") and attr.endswith("__"):
#     125     raise AttributeError(
#     126         f"{type(self).__name__} object has no attribute {attr!r}"
#     127     )
# --> 129 self.__load()
#     130 # This looks circular, but its not, since __load() changes our
#     131 # __class__ to something new:
#     132 return getattr(self, attr)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\corpus\util.py:87, in LazyCorpusLoader.__load(self)
#      85             root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      86         except LookupError:
# ---> 87             raise e
#      89 # Load the corpus.
#      90 corpus = self.__reader_cls(root, *self.__args, **self.__kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\corpus\util.py:82, in LazyCorpusLoader.__load(self)
#      80 else:
#      81     try:
# ---> 82         root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      83     except LookupError as e:
#      84         try:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\nltk\data.py:738, in find(resource_name, paths)
#     736 sep = "*" * 70
#     737 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 738 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource 'stopwords' not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load 'corpora/stopwords'
#
#   Searched in:
#     - 'C:\\Users\\school/nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\share\\nltk_data'
#     - 'C:\\Program Files\\WindowsApps\\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\\lib\\nltk_data'
#     - 'C:\\Users\\school\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.lancaster import LancasterStemmer

p_stemmer = PorterStemmer()
s_stemmer = SnowballStemmer(ignore_stopwords=True, language='english')
l_stemmer = LancasterStemmer()
# VOCAB['p_stem'] = VOCAB.apply(lambda x: stemmer.stem(x.name), 1)
# VOCAB['p_stem'] = VOCAB.reset_index().term_str.apply(stemmer.stem)
VOCAB['p_stem'] = [p_stemmer.stem(term_str) for term_str in VOCAB.index]
VOCAB['s_stem'] = [s_stemmer.stem(term_str) for term_str in VOCAB.index]
VOCAB['l_stem'] = [l_stemmer.stem(term_str) for term_str in VOCAB.index]
VOCAB

# %%
VOCAB.to_csv('Data\VOCAB\FULL_VOCAB.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# <>:1: SyntaxWarning: invalid escape sequence '\V'
# C:\Users\school\AppData\Local\Temp\ipykernel_89888\1594210221.py:1: SyntaxWarning: invalid escape sequence '\V'
#   VOCAB.to_csv('Data\VOCAB\FULL_VOCAB.csv')
