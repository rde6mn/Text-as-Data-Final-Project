# %%
import pandas as pd

ALL_TOKENS = pd.read_csv('Data\CORPUS\FULL_CORPUS.csv')
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# <>:3: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\school\AppData\Local\Temp\ipykernel_100900\2844328.py:3: SyntaxWarning: invalid escape sequence '\C'
#   ALL_TOKENS = pd.read_csv('Data\CORPUS\FULL_CORPUS.csv')
# C:\Users\school\AppData\Local\Temp\ipykernel_100900\2844328.py:3: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   ALL_TOKENS = pd.read_csv('Data\CORPUS\FULL_CORPUS.csv')

# %%
book_id = [3268, 5182, 696, 53685, 84, 6087, 43, 345, 1952, 175, 12122, 20180856]
short_name = ["udolpho", "baron", "otranto" , "melmoth", "frankenstein", "vampyre", "jekyll", "dracula", "yellow_walpaper", "phantom_of_the_opera", "monkey_paw", "haunting_of_hill_house"]
era = ["high", "high", "high", "classic","classic", "classic" , "victorian", "victorian", "victorian", "modern", "modern", "modern"]
date = [1794, 1778, 1764, 1820, 1818, 1819, 1886, 1897, 1892, 1910, 1902, 1959]
novel_type = ['romance', 'horror', 'romance', 'horror','horror','horror','thriller','horror', 'horror','romance', 'horror','thriller']

# %%
LIB = pd.DataFrame({
    "book_id": book_id,
    "short_name": short_name,
    "era": era,
    "date": date,
    "novel_type": novel_type
}).set_index('book_id').sort_index()
LIB
# Out:
#                       short_name        era  date novel_type
# book_id
# 43                        jekyll  victorian  1886   thriller
# 84                  frankenstein    classic  1818     horror
# 175         phantom_of_the_opera     modern  1910    romance
# 345                      dracula  victorian  1897     horror
# 696                      otranto       high  1764    romance
# 1952             yellow_walpaper  victorian  1892     horror
# 3268                     udolpho       high  1794    romance
# 5182                       baron       high  1778     horror
# 6087                     vampyre    classic  1819     horror
# 12122                 monkey_paw     modern  1902     horror
# 53685                    melmoth    classic  1820     horror
# 20180856  haunting_of_hill_house     modern  1959   thriller

# %%
LIB.to_csv('Data\LIB.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# <>:1: SyntaxWarning: invalid escape sequence '\L'
# C:\Users\school\AppData\Local\Temp\ipykernel_100900\3813538324.py:1: SyntaxWarning: invalid escape sequence '\L'
#   LIB.to_csv('Data\LIB.csv')
